# %%
import numpy as np
import pandas as pd
heroes = pd.read_csv("heroes_information.csv")

# %%
###instalar desde anaconda navigator######
from pandasql import *

# %%
pysqldf = lambda q: sqldf(q,globals())

# %%
query2 = " SELECT * FROM heroes limit 10"

# %%
pysqldf(query2)
# Out:
#    id           name  Gender Eye color               Race Hair color  Height  \
# 0   0         A-Bomb    Male    yellow              Human    No Hair   203.0
# 1   1     Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2   2       Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3   3    Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4   4        Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5   5  Absorbing Man    Male      blue              Human    No Hair   193.0
# 6   6    Adam Monroe    Male      blue               None      Blond   -99.0
# 7   7   Adam Strange    Male      blue              Human      Blond   185.0
# 8   8       Agent 13  Female      blue               None      Blond   173.0
# 9   9      Agent Bob    Male     brown              Human      Brown   178.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics       None      good   441.0
# ...

# %%
query1 = " SELECT name, Gender  FROM heroes limit 2"

# %%
pysqldf(query1)
# Out:
#          name Gender
# 0      A-Bomb   Male
# 1  Abe Sapien   Male

# %%
query3 = " SELECT name from heroes"

# %%
pysqldf(query3)
# Out:
#                 name
# 0             A-Bomb
# 1         Abe Sapien
# 2           Abin Sur
# 3        Abomination
# 4            Abraxas
# ..               ...
# 729  Yellowjacket II
# 730             Ymir
# 731             Yoda
# 732          Zatanna
# 733             Zoom
#
# [734 rows x 1 columns]

# %%
query4 = " SELECT distinct publisher FROM heroes"

# %%
pysqldf(query4)
# Out:
#             Publisher
# 0       Marvel Comics
# 1   Dark Horse Comics
# 2           DC Comics
# 3        NBC - Heroes
# 4           Wildstorm
# 5        Image Comics
# 6                None
# 7         Icon Comics
# 8                SyFy
# 9       Hanna-Barbera
# 10       George Lucas
# 11       Team Epic TV
# 12         South Park
# 13      HarperCollins
# 14        ABC Studios
# 15  Universal Studios
# 16          Star Trek
# 17     IDW Publishing
# 18           Shueisha
# 19      Sony Pictures
# 20      J. K. Rowling
# 21        Titan Books
# 22          Rebellion
# 23          Microsoft
# 24   J. R. R. Tolkien

# %%
query5 = " SELECT * FROM heroes where height>200"

# %%
pysqldf(query5)
# Out:
#      id               name  Gender Eye color               Race Hair color  \
# 0     0             A-Bomb    Male    yellow              Human    No Hair
# 1     3        Abomination    Male     green  Human / Radiation    No Hair
# 2    17              Alien    Male      None    Xenomorph XX121    No Hair
# 3    19              Amazo    Male       red            Android       None
# 4    29            Ant-Man    Male      blue              Human      Blond
# 5    33         Anti-Venom    Male      blue           Symbiote      Blond
# 6    34         Apocalypse    Male       red             Mutant      Black
# 7    59               Bane    Male      None              Human       None
# 8    78      Beta Ray Bill    Male      None               None    No Hair
# 9   119           Bloodaxe  Female      blue              Human      Brown
# 10  144              Cable    Male      blue             Mutant      White
# ...

# %%
query6 = " SELECT * FROM heroes where Race='Human' and Height>200"

# %%
pysqldf(query6)
# Out:
#      id           name  Gender Eye color   Race Hair color  Height  \
# 0     0         A-Bomb    Male    yellow  Human    No Hair   203.0
# 1    29        Ant-Man    Male      blue  Human      Blond   211.0
# 2    59           Bane    Male      None  Human       None   203.0
# 3   119       Bloodaxe  Female      blue  Human      Brown   218.0
# 4   221    Doctor Doom    Male     brown  Human      Brown   201.0
# 5   373     Juggernaut    Male      blue  Human        Red   287.0
# 6   391        Kingpin    Male      blue  Human    No Hair   201.0
# 7   412         Lizard    Male       red  Human    No Hair   203.0
# 8   476  Mr Incredible    Male      blue  Human      Blond   201.0
# 9   557            Rey  Female     hazel  Human      Brown   297.0
# 10  583       Scorpion    Male     brown  Human      Brown   211.0
# 11  591       She-Hulk  Female     green  Human      Green   201.0
#
#             Publisher Skin color Alignment  Weight
# ...

# %%
query7 = " SELECT * FROM heroes where weight between 100 and 200 "

# %%
pysqldf(query7)
# Out:
#      id            name Gender Eye color             Race Hair color  Height  \
# 0     5   Absorbing Man   Male      blue            Human    No Hair   193.0
# 1    10      Agent Zero   Male      None             None       None   191.0
# 2    11      Air-Walker   Male      blue             None      White   188.0
# 3    17           Alien   Male      None  Xenomorph XX121    No Hair   244.0
# 4    19           Amazo   Male       red          Android       None   257.0
# ..  ...             ...    ...       ...              ...        ...     ...
# 93  709         Warpath   Male     brown           Mutant      Black   218.0
# 94  716  Winter Soldier   Male     brown            Human      Brown   175.0
# 95  719       Wolverine   Male      blue           Mutant      Black   160.0
# 96  721      Wonder Man   Male       red             None      Black   188.0
# 97  724  Wyatt Wingfoot   Male     brown             None      Black   196.0
#
# ...

# %%
query8 = " SELECT * FROM heroes where [Eye color]= 'red' or [Eye color]= 'blue'"

# %%
pysqldf(query8)
# Out:
#       id             name  Gender Eye color           Race        Hair color  \
# 0      1       Abe Sapien    Male      blue  Icthyo Sapien           No Hair
# 1      2         Abin Sur    Male      blue        Ungaran           No Hair
# 2      4          Abraxas    Male      blue  Cosmic Entity             Black
# 3      5    Absorbing Man    Male      blue          Human           No Hair
# 4      6      Adam Monroe    Male      blue           None             Blond
# ..   ...              ...     ...       ...            ...               ...
# 266  727      Yellow Claw    Male      blue           None           No Hair
# 267  728     Yellowjacket    Male      blue          Human             Blond
# 268  729  Yellowjacket II  Female      blue          Human  Strawberry Blond
# 269  732          Zatanna  Female      blue          Human             Black
# 270  733             Zoom    Male       red           None             Brown
#
# ...

# %%
query9 = " SELECT * FROM heroes where 'Eye color'= 'red' or 'Eye color'= 'blue'"

# %%
pysqldf(query9)
# Out:
# Empty DataFrame
# Columns: [id, name, Gender, Eye color, Race, Hair color, Height, Publisher, Skin color, Alignment, Weight]
# Index: []

# %%
query10 = " SELECT * FROM heroes order by Race desc   "

# %%
pysqldf(query10)
# Out:
#       id            name  Gender Eye color             Race Hair color  \
# 0    611  Solomon Grundy    Male     black           Zombie      White
# 1    274          Gamora  Female    yellow    Zen-Whoberian      Black
# 2    731            Yoda    Male     brown   Yoda's species      White
# 3    527        Predator    Male      None           Yautja       None
# 4     17           Alien    Male      None  Xenomorph XX121    No Hair
# ..   ...             ...     ...       ...              ...        ...
# 729  723          Wondra  Female      None             None       None
# 730  724  Wyatt Wingfoot    Male     brown             None      Black
# 731  726           X-Man    Male      blue             None      Brown
# 732  727     Yellow Claw    Male      blue             None    No Hair
# 733  733            Zoom    Male       red             None      Brown
#
#      Height          Publisher Skin color Alignment  Weight
# ...

# %%
query11 = " SELECT count(Gender) FROM heroes group by Gender  "

# %%
pysqldf(query11)
# Out:
#    count(Gender)
# 0              0
# 1            200
# 2            505

# %%
query12 = " SELECT count(*) FROM heroes group by Publisher having count()>15 "

# %%
pysqldf(query12)
# Out:
#    count(*)
# 0       215
# 1        18
# 2       388
# 3        19
