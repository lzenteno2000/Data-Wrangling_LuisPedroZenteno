# %% [markdown]
# ## What is Feature Engineering

# %% [markdown]
# Data comes in many formats: raw, unstructured, bad, incomplete, or large. Therefore, transformations and procedures are needed to get actionable data to model, analyze, or get insights for a business unit.

# %% [markdown]
# <img src='mental_map.png'/>

# %% [markdown]
# After we have the raw data into a tidy standard, we can then start performing feature engineering. A feature is known to be a variable or a characteristic of the observation we want to model or analyze.

# %% [markdown]
# ## Why Python?

# %% [markdown]
# <img src='intro.png'/>

# %% [markdown]
# ## Anaconda Distribution

# %% [markdown]
# <img src='conda_envs.png'/>

# %% [markdown]
# ## Loading Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
rating = pd.read_csv('restaurant-data-with-consumer-ratings/rating_final.csv')
users = pd.read_csv('restaurant-data-with-consumer-ratings/userprofile.csv')

# %%
print('Rating dataset shape:', rating.shape)
rating.head()
# Out:
# Rating dataset shape: (1161, 5)
#   userID  placeID  rating  food_rating  service_rating
# 0  U1077   135085       2            2               2
# 1  U1077   135038       2            2               1
# 2  U1077   132825       2            2               2
# 3  U1077   135060       1            2               2
# 4  U1068   135104       1            1               2

# %%
print('Users dataset shape:', users.shape)
users.head()
# Out:
# Users dataset shape: (138, 19)
#   userID   latitude   longitude smoker     drink_level dress_preference  \
# 0  U1001  22.139997 -100.978803  false      abstemious         informal
# 1  U1002  22.150087 -100.983325  false      abstemious         informal
# 2  U1003  22.119847 -100.946527  false  social drinker           formal
# 3  U1004  18.867000  -99.183000  false      abstemious         informal
# 4  U1005  22.183477 -100.959891  false      abstemious    no preference
#
#   ambience transport marital_status        hijos  birth_year    interest  \
# 0   family   on foot         single  independent        1989     variety
# 1   family    public         single  independent        1990  technology
# 2   family    public         single  independent        1989        none
# 3   family    public         single  independent        1940     variety
# 4   family    public         single  independent        1992        none
#
#            personality  religion      activity  color  weight  budget  height
# 0    thrifty-protector      none       student  black      69  medium    1.77
# 1  hunter-ostentatious  Catholic       student    red      40     low    1.87
# 2          hard-worker  Catholic       student   blue      60     low    1.69
# 3          hard-worker      none  professional  green      44  medium    1.53
# 4    thrifty-protector  Catholic       student  black      65  medium    1.69

# %%
df = rating.merge(users, how = 'left', on = 'userID')

# %%
print('Final dataset shape:', df.shape)
df.head()
# Out:
# Final dataset shape: (1161, 23)
#   userID  placeID  rating  food_rating  service_rating   latitude   longitude  \
# 0  U1077   135085       2            2               2  22.156469 -100.985540
# 1  U1077   135038       2            2               1  22.156469 -100.985540
# 2  U1077   132825       2            2               2  22.156469 -100.985540
# 3  U1077   135060       1            2               2  22.156469 -100.985540
# 4  U1068   135104       1            1               2  23.752269  -99.168605
#
#   smoker     drink_level dress_preference  ...        hijos birth_year  \
# 0  false  social drinker          elegant  ...         kids       1987
# 1  false  social drinker          elegant  ...         kids       1987
# 2  false  social drinker          elegant  ...         kids       1987
# 3  false  social drinker          elegant  ...         kids       1987
# 4  false  casual drinker         informal  ...  independent       1988
#
#      interest        personality  religion activity color weight  budget  \
# 0  technology  thrifty-protector  Catholic  student  blue     65  medium
# 1  technology  thrifty-protector  Catholic  student  blue     65  medium
# 2  technology  thrifty-protector  Catholic  student  blue     65  medium
# 3  technology  thrifty-protector  Catholic  student  blue     65  medium
# 4  technology  thrifty-protector  Catholic  student  blue     72     low
#
#   height
# 0   1.71
# 1   1.71
# 2   1.71
# 3   1.71
# 4   1.57
#
# [5 rows x 23 columns]

# %%
df.describe()
# Out:
#              placeID       rating  food_rating  service_rating     latitude  \
# count    1161.000000  1161.000000  1161.000000     1161.000000  1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439    21.893060
# std      1100.916275     0.773282     0.792294        0.790844     1.308759
# min    132560.000000     0.000000     0.000000        0.000000    18.813348
# 25%    132856.000000     1.000000     1.000000        0.000000    22.138127
# 50%    135030.000000     1.000000     1.000000        1.000000    22.150891
# 75%    135059.000000     2.000000     2.000000        2.000000    22.177726
# max    135109.000000     2.000000     2.000000        2.000000    23.771030
#
#          longitude   birth_year       weight       height
# count  1161.000000  1161.000000  1161.000000  1161.000000
# mean   -100.496817  1983.934539    63.241171     1.662842
# std       0.788721    16.305780    16.221539     0.135386
# min    -101.054680  1930.000000    40.000000     1.200000
# 25%    -100.984268  1987.000000    52.000000     1.600000
# 50%    -100.947888  1989.000000    64.000000     1.690000
# 75%     -99.250000  1991.000000    70.000000     1.750000
# max     -99.067106  1994.000000   120.000000     2.000000

# %% [markdown]
# ## 1. Missing Data

# %% [markdown]
# A review of techniques for treating missing data in OM survey research
#
# by Nikos Tsikriktsis

# %% [markdown]
# <img src='paper.png'/>

# %% [markdown]
# * NA
# * NULL
# * blank
# * 0, 99, 999
#
# Are NA and <blank> the same?
# Can we handle missing data as part of the test set?
# Some ML, DL... algorithms drop NA values… some give errors

# %% [markdown]
# ### Dealing with missing data
#
# Finding NAs in the dataset

# %%
df.isna().sum() #or df.isnull().sum()
# Out:
# userID              0
# placeID             0
# rating              0
# food_rating         0
# service_rating      0
# latitude            0
# longitude           0
# smoker              0
# drink_level         0
# dress_preference    0
# ambience            0
# transport           0
# marital_status      0
# hijos               0
# birth_year          0
# interest            0
# personality         0
# religion            0
# activity            0
# color               0
# weight              0
# budget              0
# height              0
# dtype: int64

# %%
np.unique(df['smoker'])
# Out:
# array(['?', 'false', 'true'], dtype=object)

# %%
cols = []
val = []
for col in df.select_dtypes(include='object').columns:
    cols.append(col)
    val.append(df[col].str.contains(r'\?').sum())
pd.DataFrame({
    'cols':cols,
    'val':val
})
# Out:
#                 cols  val
# 0             userID    0
# 1             smoker   31
# 2        drink_level    0
# 3   dress_preference   51
# 4           ambience   58
# 5          transport   54
# 6     marital_status   40
# 7              hijos   98
# 8           interest    0
# 9        personality    0
# 10          religion    0
# 11          activity   53
# 12             color    0
# 13            budget   69

# %% [markdown]
# We need to change the **?** into a **NaN** value

# %%
df.replace(r'\?', np.nan, regex = True, inplace = True)

# %% [markdown]
# Checking again for missing values

# %%
df.isna().sum()
# Out:
# userID               0
# placeID              0
# rating               0
# food_rating          0
# service_rating       0
# latitude             0
# longitude            0
# smoker              31
# drink_level          0
# dress_preference    51
# ambience            58
# transport           54
# marital_status      40
# hijos               98
# birth_year           0
# interest             0
# personality          0
# religion             0
# activity            53
# color                0
# weight               0
# budget              69
# height               0
# dtype: int64

# %% [markdown]
# ### 1.1 Deletion

# %% [markdown]
# ### Listwise

# %% [markdown]
# <img src='listwise.png'/>

# %%
df.dropna().shape
# Out:
# (997, 23)

# %% [markdown]
# ### Pairwise

# %% [markdown]
# <img src='corr.png'/>

# %%
df.corr()
# Out:
#                  placeID    rating  food_rating  service_rating  latitude  \
# placeID         1.000000  0.073768     0.011680        0.059236 -0.226728
# rating          0.073768  1.000000     0.714855        0.690757 -0.122537
# food_rating     0.011680  0.714855     1.000000        0.647177 -0.068943
# service_rating  0.059236  0.690757     0.647177        1.000000 -0.083278
# latitude       -0.226728 -0.122537    -0.068943       -0.083278  1.000000
# longitude      -0.212708 -0.046466    -0.007731       -0.053349 -0.332118
# birth_year     -0.065294 -0.134949    -0.122824       -0.122814  0.199679
# weight         -0.169660 -0.069134    -0.036307       -0.034898  0.107755
# height         -0.090682  0.017379     0.013336        0.031252  0.052327
#
#                 longitude  birth_year    weight    height
# placeID         -0.212708   -0.065294 -0.169660 -0.090682
# rating          -0.046466   -0.134949 -0.069134  0.017379
# food_rating     -0.007731   -0.122824 -0.036307  0.013336
# service_rating  -0.053349   -0.122814 -0.034898  0.031252
# latitude        -0.332118    0.199679  0.107755  0.052327
# longitude        1.000000   -0.056088  0.151532  0.024248
# birth_year      -0.056088    1.000000  0.189881  0.292179
# weight           0.151532    0.189881  1.000000  0.500988
# height           0.024248    0.292179  0.500988  1.000000

# %%
df[['rating', 'food_rating']].corr()
# Out:
#                rating  food_rating
# rating       1.000000     0.714855
# food_rating  0.714855     1.000000

# %% [markdown]
# ### 1.2 Filling and dropping values

# %% [markdown]
# **Filling Values**
#
# * Fill values with information available (time series for example)
# * Nearest Neighbor Imputation (NNI) - surveys - distance minimization
# * KNN models
#
# **Advantages:** Not losing observations.
#
# **Disadvantages:** Missing the target.

# %% [markdown]
# <img src='fill.png'/>

# %%
df.iloc[380:390]
# Out:
#     userID  placeID  rating  food_rating  service_rating   latitude  \
# 380  U1115   135108       1            2               2  22.138127
# 381  U1115   135069       1            0               1  22.138127
# 382  U1115   132830       2            2               2  22.138127
# 383  U1115   135070       1            1               1  22.138127
# 384  U1115   135071       2            2               2  22.138127
# 385  U1072   135000       0            0               0  18.868260
# 386  U1024   132834       1            1               1  22.154021
# 387  U1024   135106       1            1               1  22.154021
# 388  U1024   135042       1            2               1  22.154021
# 389  U1024   132825       1            1               0  22.154021
#
#       longitude smoker     drink_level dress_preference  ...        hijos  \
# 380 -100.920512   true  social drinker          elegant  ...  independent
# 381 -100.920512   true  social drinker          elegant  ...  independent
# 382 -100.920512   true  social drinker          elegant  ...  independent
# 383 -100.920512   true  social drinker          elegant  ...  independent
# 384 -100.920512   true  social drinker          elegant  ...  independent
# 385  -99.212033  false  casual drinker    no preference  ...  independent
# 386 -100.976028    NaN      abstemious              NaN  ...          NaN
# 387 -100.976028    NaN      abstemious              NaN  ...          NaN
# 388 -100.976028    NaN      abstemious              NaN  ...          NaN
# 389 -100.976028    NaN      abstemious              NaN  ...          NaN
#
#     birth_year      interest        personality   religion activity   color  \
# 380       1990       variety        hard-worker   Catholic  student   green
# 381       1990       variety        hard-worker   Catholic  student   green
# 382       1990       variety        hard-worker   Catholic  student   green
# 383       1990       variety        hard-worker   Catholic  student   green
# 384       1990       variety        hard-worker   Catholic  student   green
# 385       1984  eco-friendly  thrifty-protector  Christian  student     red
# 386       1930          none        hard-worker       none      NaN  yellow
# 387       1930          none        hard-worker       none      NaN  yellow
# 388       1930          none        hard-worker       none      NaN  yellow
# 389       1930          none        hard-worker       none      NaN  yellow
#
#     weight  budget height
# 380     76     low   1.76
# 381     76     low   1.76
# 382     76     low   1.76
# 383     76     low   1.76
# 384     76     low   1.76
# 385     50  medium   1.54
# 386     40     NaN   1.20
# 387     40     NaN   1.20
# 388     40     NaN   1.20
# 389     40     NaN   1.20
#
# [10 rows x 23 columns]

# %%
df.fillna(method='ffill').iloc[380:390]
# Out:
#     userID  placeID  rating  food_rating  service_rating   latitude  \
# 380  U1115   135108       1            2               2  22.138127
# 381  U1115   135069       1            0               1  22.138127
# 382  U1115   132830       2            2               2  22.138127
# 383  U1115   135070       1            1               1  22.138127
# 384  U1115   135071       2            2               2  22.138127
# 385  U1072   135000       0            0               0  18.868260
# 386  U1024   132834       1            1               1  22.154021
# 387  U1024   135106       1            1               1  22.154021
# 388  U1024   135042       1            2               1  22.154021
# 389  U1024   132825       1            1               0  22.154021
#
#       longitude smoker     drink_level dress_preference  ...        hijos  \
# 380 -100.920512   true  social drinker          elegant  ...  independent
# 381 -100.920512   true  social drinker          elegant  ...  independent
# 382 -100.920512   true  social drinker          elegant  ...  independent
# 383 -100.920512   true  social drinker          elegant  ...  independent
# 384 -100.920512   true  social drinker          elegant  ...  independent
# 385  -99.212033  false  casual drinker    no preference  ...  independent
# 386 -100.976028  false      abstemious    no preference  ...  independent
# 387 -100.976028  false      abstemious    no preference  ...  independent
# 388 -100.976028  false      abstemious    no preference  ...  independent
# 389 -100.976028  false      abstemious    no preference  ...  independent
#
#     birth_year      interest        personality   religion activity   color  \
# 380       1990       variety        hard-worker   Catholic  student   green
# 381       1990       variety        hard-worker   Catholic  student   green
# 382       1990       variety        hard-worker   Catholic  student   green
# 383       1990       variety        hard-worker   Catholic  student   green
# 384       1990       variety        hard-worker   Catholic  student   green
# 385       1984  eco-friendly  thrifty-protector  Christian  student     red
# 386       1930          none        hard-worker       none  student  yellow
# 387       1930          none        hard-worker       none  student  yellow
# 388       1930          none        hard-worker       none  student  yellow
# 389       1930          none        hard-worker       none  student  yellow
#
#     weight  budget height
# 380     76     low   1.76
# 381     76     low   1.76
# 382     76     low   1.76
# 383     76     low   1.76
# 384     76     low   1.76
# 385     50  medium   1.54
# 386     40  medium   1.20
# 387     40  medium   1.20
# 388     40  medium   1.20
# 389     40  medium   1.20
#
# [10 rows x 23 columns]

# %% [markdown]
# Now, for dropping a column, we can choose a threshold. If % of NAs are higher than the threshold then we remove the column.

# %%
pct = pd.DataFrame(df.isna().sum()/df.shape[0], columns = ['pct']).reset_index()
pct
# Out:
#                index       pct
# 0             userID  0.000000
# 1            placeID  0.000000
# 2             rating  0.000000
# 3        food_rating  0.000000
# 4     service_rating  0.000000
# 5           latitude  0.000000
# 6          longitude  0.000000
# 7             smoker  0.026701
# 8        drink_level  0.000000
# 9   dress_preference  0.043928
# 10          ambience  0.049957
# 11         transport  0.046512
# 12    marital_status  0.034453
# 13             hijos  0.084410
# 14        birth_year  0.000000
# 15          interest  0.000000
# 16       personality  0.000000
# 17          religion  0.000000
# 18          activity  0.045650
# 19             color  0.000000
# 20            weight  0.000000
# 21            budget  0.059432
# 22            height  0.000000

# %% [markdown]
# **Dropping Values**
#
# * Dropping features lower than a threshold (70% for example)
#
# **Advantages:** Not using features with many NA. Can alter our model.
#
# **Disadvantages:** Losing information

# %%
threshold = 0.70
cols_keep = pct[pct['pct']<threshold]['index'].values
cols_keep
# Out:
# array(['userID', 'placeID', 'rating', 'food_rating', 'service_rating',
#        'latitude', 'longitude', 'smoker', 'drink_level',
#        'dress_preference', 'ambience', 'transport', 'marital_status',
#        'hijos', 'birth_year', 'interest', 'personality', 'religion',
#        'activity', 'color', 'weight', 'budget', 'height'], dtype=object)

# %%
df[cols_keep]
# Out:
#      userID  placeID  rating  food_rating  service_rating   latitude  \
# 0     U1077   135085       2            2               2  22.156469
# 1     U1077   135038       2            2               1  22.156469
# 2     U1077   132825       2            2               2  22.156469
# 3     U1077   135060       1            2               2  22.156469
# 4     U1068   135104       1            1               2  23.752269
# ...     ...      ...     ...          ...             ...        ...
# 1156  U1043   132630       1            1               1  23.771030
# 1157  U1011   132715       1            1               0  23.724972
# 1158  U1068   132733       1            1               0  23.752269
# 1159  U1068   132594       1            1               1  23.752269
# 1160  U1068   132660       0            0               0  23.752269
#
#        longitude smoker     drink_level dress_preference  ...        hijos  \
# 0    -100.985540  false  social drinker          elegant  ...         kids
# 1    -100.985540  false  social drinker          elegant  ...         kids
# 2    -100.985540  false  social drinker          elegant  ...         kids
# 3    -100.985540  false  social drinker          elegant  ...         kids
# 4     -99.168605  false  casual drinker         informal  ...  independent
# ...          ...    ...             ...              ...  ...          ...
# 1156  -99.167082  false      abstemious    no preference  ...  independent
# 1157  -99.152856  false      abstemious    no preference  ...  independent
# 1158  -99.168605  false  casual drinker         informal  ...  independent
# 1159  -99.168605  false  casual drinker         informal  ...  independent
# 1160  -99.168605  false  casual drinker         informal  ...  independent
#
#      birth_year    interest        personality  religion activity   color  \
# 0          1987  technology  thrifty-protector  Catholic  student    blue
# 1          1987  technology  thrifty-protector  Catholic  student    blue
# 2          1987  technology  thrifty-protector  Catholic  student    blue
# 3          1987  technology  thrifty-protector  Catholic  student    blue
# 4          1988  technology  thrifty-protector  Catholic  student    blue
# ...         ...         ...                ...       ...      ...     ...
# 1156       1989  technology        hard-worker      none  student   white
# 1157       1989     variety        hard-worker  Catholic  student  purple
# 1158       1988  technology  thrifty-protector  Catholic  student    blue
# 1159       1988  technology  thrifty-protector  Catholic  student    blue
# 1160       1988  technology  thrifty-protector  Catholic  student    blue
#
#      weight  budget height
# 0        65  medium   1.71
# 1        65  medium   1.71
# 2        65  medium   1.71
# 3        65  medium   1.71
# 4        72     low   1.57
# ...     ...     ...    ...
# 1156     60  medium   1.64
# 1157     68  medium   1.78
# 1158     72     low   1.57
# 1159     72     low   1.57
# 1160     72     low   1.57
#
# [1161 rows x 23 columns]

# %% [markdown]
# ### 1.3 Imputations

# %% [markdown]
# * Mean: maintains the average of each feature
# * Mode: most repeated value (stats change)
# * Median: median value (stats change)
# * Constant: Adding a constant to all missing values (stats changes but functions become available without na.rm)
#
# There are some ways of imputing a variable. Some of them are:
# * Base python: finding NAs and then assign a forced value (mean, median, constant)
# * scipy: finding NAs and then assign a forced value (mode: categorical)
# * sklearn: apply sklearn function with a specific strategy

# %% [markdown]
# Base python

# %%
df[df['weight'].isna()]['weight'] = df['weight'].mean()

# %% [markdown]
# Scipy

# %%
from scipy import stats

# %%
stats.mode(df['smoker'])
# Out:
# ModeResult(mode=array(['false'], dtype=object), count=array([907]))

# %% [markdown]
# Sklearn

# %%
from sklearn.impute import SimpleImputer

# %%
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
imp_mode = SimpleImputer(missing_values=np.nan, strategy='most_frequent')

# %%
imp_mean.fit_transform(df[['weight']])
# Out:
# array([[65.],
#        [65.],
#        [65.],
#        ...,
#        [72.],
#        [72.],
#        [72.]])

# %%
imp_mode.fit_transform(df[['smoker']])
# Out:
# array([['false'],
#        ['false'],
#        ['false'],
#        ...,
#        ['false'],
#        ['false'],
#        ['false']], dtype=object)

# %% [markdown]
# Now, if we want sectorized imputations, we need to create a **dictionary** or use **pd.cut()** function
#
# * Using mean/mode/median or 0 imputation by feature.
# * Mode is needed for categorical features
#
# Disadvantage: Data is now highly biased

# %%
#For Smokers by Drink Level and Personality
dic_smoker = pd.DataFrame(df.groupby(['drink_level', 'personality'])['smoker'].agg(lambda x:x.value_counts().index[0])) \
    .reset_index()
dic_smoker.columns = ['drink_level', 'personality', 'smoker_new']
dic_smoker
# Out:
#        drink_level          personality smoker_new
# 0       abstemious           conformist      false
# 1       abstemious          hard-worker      false
# 2       abstemious  hunter-ostentatious      false
# 3       abstemious    thrifty-protector      false
# 4   casual drinker           conformist       true
# 5   casual drinker          hard-worker      false
# 6   casual drinker  hunter-ostentatious      false
# 7   casual drinker    thrifty-protector      false
# 8   social drinker           conformist       true
# 9   social drinker          hard-worker      false
# 10  social drinker  hunter-ostentatious       true
# 11  social drinker    thrifty-protector      false

# %%
df = df.merge(dic_smoker, how = 'left', on = ['drink_level', 'personality'])
df['smoker_new_2'] = np.where(df['smoker'].isna(), df['smoker_new'], df['smoker'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(df[df['smoker'].notna()]['smoker'])

# %%
sns.countplot(df['smoker_new'])

# %%
sns.countplot(df['smoker_new_2'])

# %% [markdown]
# ### 1.4 Predictive Models

# %% [markdown]
# Predictive models are used to choose the best approximation for a missing value.
#
# Numerical features:
# * Linear regression
# * Multidimensional regression
#
# Categorial features:
# * K-Nearest neighbors (KNN)
# * Support vector machines (SVM)
# * Logistic regression

# %% [markdown]
# ***Linear Model Example***

# %% [markdown]
# <img src='lm.png'/>

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()
lm = lm.fit(df[['height']], df['weight'])
lm
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
df['weight_lm'] = lm.predict(df[['height']])

# %%
print('Weight avg without prediction:', round(df['weight'].mean(),2))
sns.distplot(df['weight'])
# Out:
# Weight avg without prediction: 63.24

# %%
print('Weight avg after prediction:', round(df['weight_lm'].mean(),2))
print('y_hat = ', round(lm.intercept_,2), ' + ', round(lm.coef_[0],2), 'x', sep = '')
sns.scatterplot(x = df['height'], y = df['weight'])
sns.lineplot(x = df['height'], y = lm.intercept_ + (lm.coef_ * df['height']))
plt.ylabel('weight')
plt.show()
sns.distplot(df['weight_lm'])
plt.show()
# Out:
# Weight avg after prediction: 63.24
# y_hat = -36.57 + 60.03x

# %% [markdown]
# ## 2. Outliers

# %% [markdown]
# ### 2.1 Standard Deviation Approach

# %% [markdown]
# All values with a distance to the average of **factor * standard deviation** are assumed to be outliers.
#
# How we choose a factor? (2-4 recommended) ***We can also use Z value***
#
# We can drop the Outliers from our data or we can “Cap” those values. For the observations with a value under the lower limit, we use the lower limit instead; the same for the upper values.

# %% [markdown]
# $$
# x_{l} = \mu_{var} - \sigma_{var}x_{i} \\
# x_{u} = \mu_{var} + \sigma_{var}x_{i}
# $$

# %%
f = 2
xl = df['weight'].mean() - (df['weight'].std() * f)
xu = df['weight'].mean() + (df['weight'].std() * f)
print('Lower value:', xl)
print('Upper value:', xu)
# Out:
# Lower value: 30.798092762318078
# Upper value: 95.68425004560612

# %%
sns.scatterplot(x = df['userID'], y = df['weight'])
sns.lineplot(x = df['userID'], y = xl, color = 'green')
sns.lineplot(x = df['userID'], y = xu, color = 'orange')

# %% [markdown]
# If you want to delete every observation containing an outlier:

# %%
df_sd = df[(df['weight']>=xl) & (df['weight']<=xu)]

# %%
df_sd[['weight']].describe()
# Out:
#             weight
# count  1117.000000
# mean     61.391226
# std      13.423687
# min      40.000000
# 25%      52.000000
# 50%      62.000000
# 75%      70.000000
# max      94.000000

# %% [markdown]
# Now we need to ***cap*** the values in the limits

# %%
df['weight_sd'] = np.where(
    df['weight']<xl,
    xl,
    np.where(
        df['weight']>xu,
        xu,
        df['weight']
    )
)

# %%
df[['weight', 'weight_sd']].describe()
# Out:
#             weight    weight_sd
# count  1161.000000  1161.000000
# mean     63.241171    62.690876
# std      16.221539    14.706365
# min      40.000000    40.000000
# 25%      52.000000    52.000000
# 50%      64.000000    64.000000
# 75%      70.000000    70.000000
# max     120.000000    95.684250

# %% [markdown]
# ### 2.2 Percentile Approach

# %% [markdown]
# Percentiles do take into account the distribution minimum values, while standard deviation don't.

# %%
pl = np.percentile(df['weight'], 5)
pu = np.percentile(df['weight'], 95)

# %%
sns.scatterplot(x = df['userID'], y = df['weight'])
sns.lineplot(x = df['userID'], y = pl, color = 'orange')
sns.lineplot(x = df['userID'], y = pu, color = 'green')

# %% [markdown]
# For deleting all observations:

# %%
df_sd = df[(df['weight']>=pl) & (df['weight']<=pu)]

# %%
df_sd[['weight']].describe()
# Out:
#             weight
# count  1106.000000
# mean     61.077758
# std      13.114577
# min      40.000000
# 25%      52.000000
# 50%      61.500000
# 75%      69.000000
# max      90.000000

# %%
df['weight_pct'] = np.where(
    df['weight']<pl,
    pl,
    np.where(
        df['weight']>pu,
        pu,
        df['weight']
    )
)

# %%
df[['weight', 'weight_sd', 'weight_pct']].describe()
# Out:
#             weight    weight_sd   weight_pct
# count  1161.000000  1161.000000  1161.000000
# mean     63.241171    62.690876    62.447890
# std      16.221539    14.706365    14.199293
# min      40.000000    40.000000    40.000000
# 25%      52.000000    52.000000    52.000000
# 50%      64.000000    64.000000    64.000000
# 75%      70.000000    70.000000    70.000000
# max     120.000000    95.684250    90.000000

# %% [markdown]
# ## 3. Normalization

# %% [markdown]
# <img src='sklearn_preprocessing.png'/>

# %% [markdown]
# ### 3.1 Standarization (Z Value)

# %% [markdown]
# <img src='standarization.png'/>

# %% [markdown]
# $$
# z = \frac{x - \mu}{\sigma}
# $$

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
df_z = df.copy()
for col in df_z.select_dtypes(include=['float', 'int']).columns:
    df_z[col+'_z'] = scaler.fit_transform(df_z[[col]])

# %%
df_z.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating   latitude   longitude  \
# 0  U1077   135085       2            2               2  22.156469 -100.985540
# 1  U1077   135038       2            2               1  22.156469 -100.985540
# 2  U1077   132825       2            2               2  22.156469 -100.985540
# 3  U1077   135060       1            2               2  22.156469 -100.985540
# 4  U1068   135104       1            1               2  23.752269  -99.168605
#
#   smoker     drink_level dress_preference  ... food_rating_z service_rating_z  \
# 0  false  social drinker          elegant  ...      0.990802         1.150609
# 1  false  social drinker          elegant  ...      0.990802        -0.114407
# 2  false  social drinker          elegant  ...      0.990802         1.150609
# 3  false  social drinker          elegant  ...      0.990802         1.150609
# 4  false  casual drinker         informal  ...     -0.271899         1.150609
#
#   latitude_z longitude_z  birth_year_z  weight_z  height_z weight_lm_z  \
# 0   0.201353   -0.619906      0.188079  0.108472  0.348470    0.348470
# 1   0.201353   -0.619906      0.188079  0.108472  0.348470    0.348470
# 2   0.201353   -0.619906      0.188079  0.108472  0.348470    0.348470
# 3   0.201353   -0.619906      0.188079  0.108472  0.348470    0.348470
# 4   1.421201    1.684732      0.249434  0.540183 -0.686057   -0.686057
#
#   weight_sd_z weight_pct_z
# 0    0.157083     0.179812
# 1    0.157083     0.179812
# 2    0.157083     0.179812
# 3    0.157083     0.179812
# 4    0.633272     0.673007
#
# [5 rows x 40 columns]

# %%
df_z.describe()
# Out:
#              placeID       rating  food_rating  service_rating     latitude  \
# count    1161.000000  1161.000000  1161.000000     1161.000000  1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439    21.893060
# std      1100.916275     0.773282     0.792294        0.790844     1.308759
# min    132560.000000     0.000000     0.000000        0.000000    18.813348
# 25%    132856.000000     1.000000     1.000000        0.000000    22.138127
# 50%    135030.000000     1.000000     1.000000        1.000000    22.150891
# 75%    135059.000000     2.000000     2.000000        2.000000    22.177726
# max    135109.000000     2.000000     2.000000        2.000000    23.771030
#
#          longitude   birth_year       weight       height    weight_lm  ...  \
# count  1161.000000  1161.000000  1161.000000  1161.000000  1161.000000  ...
# mean   -100.496817  1983.934539    63.241171     1.662842    63.241171  ...
# std       0.788721    16.305780    16.221539     0.135386     8.126799  ...
# min    -101.054680  1930.000000    40.000000     1.200000    35.458157  ...
# 25%    -100.984268  1987.000000    52.000000     1.600000    59.468935  ...
# 50%    -100.947888  1989.000000    64.000000     1.690000    64.871361  ...
# 75%     -99.250000  1991.000000    70.000000     1.750000    68.472977  ...
# max     -99.067106  1994.000000   120.000000     2.000000    83.479714  ...
#
#        food_rating_z  service_rating_z    latitude_z   longitude_z  \
# count   1.161000e+03      1.161000e+03  1.161000e+03  1.161000e+03
# mean   -7.344111e-17     -9.180139e-17 -1.309700e-15  2.962125e-15
# std     1.000431e+00      1.000431e+00  1.000431e+00  1.000431e+00
# min    -1.534601e+00     -1.379424e+00 -2.354169e+00 -7.076051e-01
# 25%    -2.718995e-01     -1.379424e+00  1.873318e-01 -6.182930e-01
# 50%    -2.718995e-01     -1.144072e-01  1.970888e-01 -5.721478e-01
# 75%     9.908017e-01      1.150609e+00  2.176018e-01  1.581489e+00
# max     9.908017e-01      1.150609e+00  1.435542e+00  1.813476e+00
#
#        birth_year_z      weight_z      height_z   weight_lm_z   weight_sd_z  \
# count  1.161000e+03  1.161000e+03  1.161000e+03  1.161000e+03  1.161000e+03
# mean  -5.520323e-15  2.019631e-16 -1.958430e-16  7.007506e-16 -1.468822e-16
# std    1.000431e+00  1.000431e+00  1.000431e+00  1.000431e+00  1.000431e+00
# min   -3.309120e+00 -1.433353e+00 -3.420164e+00 -3.420164e+00 -1.543594e+00
# 25%    1.880794e-01 -6.932767e-01 -4.643725e-01 -4.643725e-01 -7.272690e-01
# 50%    3.107882e-01  4.679923e-02  2.006807e-01  2.006807e-01  8.905588e-02
# 75%    4.334969e-01  4.168372e-01  6.440495e-01  6.440495e-01  4.972183e-01
# max    6.175600e-01  3.500487e+00  2.491419e+00  2.491419e+00  2.244443e+00
#
#        weight_pct_z
# count  1.161000e+03
# mean  -2.754042e-17
# std    1.000431e+00
# min   -1.581597e+00
# 25%   -7.361206e-01
# 50%    1.093561e-01
# 75%    5.320944e-01
# max    1.941222e+00
#
# [8 rows x 24 columns]

# %% [markdown]
# ### 3.2 Min Max Scaler

# %% [markdown]
# <img src='min_max_scale.png'/>

# %% [markdown]
# <img src='poorly_scaled.png'/>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
df_norm = df.copy()
for col in df_norm.select_dtypes(include=['float', 'int']).columns:
    df_norm[col+'_norm'] = scaler.fit_transform(df_norm[[col]])

# %%
df_norm.head()
# Out:
#   userID  placeID  rating  food_rating  service_rating   latitude   longitude  \
# 0  U1077   135085       2            2               2  22.156469 -100.985540
# 1  U1077   135038       2            2               1  22.156469 -100.985540
# 2  U1077   132825       2            2               2  22.156469 -100.985540
# 3  U1077   135060       1            2               2  22.156469 -100.985540
# 4  U1068   135104       1            1               2  23.752269  -99.168605
#
#   smoker     drink_level dress_preference  ... food_rating_norm  \
# 0  false  social drinker          elegant  ...              1.0
# 1  false  social drinker          elegant  ...              1.0
# 2  false  social drinker          elegant  ...              1.0
# 3  false  social drinker          elegant  ...              1.0
# 4  false  casual drinker         informal  ...              0.5
#
#   service_rating_norm latitude_norm longitude_norm  birth_year_norm  \
# 0                 1.0      0.674331       0.034786         0.890625
# 1                 0.5      0.674331       0.034786         0.890625
# 2                 1.0      0.674331       0.034786         0.890625
# 3                 1.0      0.674331       0.034786         0.890625
# 4                 1.0      0.996216       0.948933         0.906250
#
#   weight_norm height_norm weight_lm_norm weight_sd_norm weight_pct_norm
# 0      0.3125      0.6375         0.6375       0.448960            0.50
# 1      0.3125      0.6375         0.6375       0.448960            0.50
# 2      0.3125      0.6375         0.6375       0.448960            0.50
# 3      0.3125      0.6375         0.6375       0.448960            0.50
# 4      0.4000      0.4625         0.4625       0.574669            0.64
#
# [5 rows x 40 columns]

# %%
df_norm.describe()
# Out:
#              placeID       rating  food_rating  service_rating     latitude  \
# count    1161.000000  1161.000000  1161.000000     1161.000000  1161.000000
# mean   134192.041344     1.199828     1.215332        1.090439    21.893060
# std      1100.916275     0.773282     0.792294        0.790844     1.308759
# min    132560.000000     0.000000     0.000000        0.000000    18.813348
# 25%    132856.000000     1.000000     1.000000        0.000000    22.138127
# 50%    135030.000000     1.000000     1.000000        1.000000    22.150891
# 75%    135059.000000     2.000000     2.000000        2.000000    22.177726
# max    135109.000000     2.000000     2.000000        2.000000    23.771030
#
#          longitude   birth_year       weight       height    weight_lm  ...  \
# count  1161.000000  1161.000000  1161.000000  1161.000000  1161.000000  ...
# mean   -100.496817  1983.934539    63.241171     1.662842    63.241171  ...
# std       0.788721    16.305780    16.221539     0.135386     8.126799  ...
# min    -101.054680  1930.000000    40.000000     1.200000    35.458157  ...
# 25%    -100.984268  1987.000000    52.000000     1.600000    59.468935  ...
# 50%    -100.947888  1989.000000    64.000000     1.690000    64.871361  ...
# 75%     -99.250000  1991.000000    70.000000     1.750000    68.472977  ...
# max     -99.067106  1994.000000   120.000000     2.000000    83.479714  ...
#
#        food_rating_norm  service_rating_norm  latitude_norm  longitude_norm  \
# count       1161.000000          1161.000000    1161.000000     1161.000000
# mean           0.607666             0.545220       0.621200        0.280675
# std            0.396147             0.395422       0.263986        0.396826
# min            0.000000             0.000000       0.000000        0.000000
# 25%            0.500000             0.000000       0.670632        0.035426
# 50%            0.500000             0.500000       0.673206        0.053730
# 75%            1.000000             1.000000       0.678619        0.907981
# max            1.000000             1.000000       1.000000        1.000000
#
#        birth_year_norm  weight_norm  height_norm  weight_lm_norm  \
# count      1161.000000  1161.000000  1161.000000     1161.000000
# mean          0.842727     0.290515     0.578553        0.578553
# std           0.254778     0.202769     0.169232        0.169232
# min           0.000000     0.000000     0.000000        0.000000
# 25%           0.890625     0.150000     0.500000        0.500000
# 50%           0.921875     0.300000     0.612500        0.612500
# 75%           0.953125     0.375000     0.687500        0.687500
# max           1.000000     1.000000     1.000000        1.000000
#
#        weight_sd_norm  weight_pct_norm
# count     1161.000000      1161.000000
# mean         0.407492         0.448958
# std          0.264103         0.283986
# min          0.000000         0.000000
# 25%          0.215501         0.240000
# 50%          0.431002         0.480000
# 75%          0.538752         0.600000
# max          1.000000         1.000000
#
# [8 rows x 24 columns]
